# %% [markdown]
# ### Task 1
# 1.1. Tạo một chương trình Python mới có tên “lastname_firstname_grade_the_exams.py.”
#
# 1.2. Viết hàm cho phép người dùng nhập tên của một tệp và truy cập đọc.
#
# 1.3. Nếu tệp tồn tại, bạn có thể in ra một thông báo xác nhận. Nếu tệp không tồn tại, hiển thị không thể tìm thấy tệp và yêu cầu nhập lại.
#
# 1.4. Sử dụng try/except để thực hiện việc này (đừng chỉ sử dụng một loạt câu lệnh “if”):

# %%
def open_file():
    try:
        while True:
            a = input("Enter file name: ")
            path = a + '.txt'
            try:
                o = open(path,'r')
            except Exception as e:
                print(f"Error: {e}")
            else: 
                print('Success Opened')
                # o.close()
                break 
    except Exception as e:
        print(e)

# %% [markdown]
# ### Task 2
# Tiếp theo, bạn sẽ cần phân tích dữ liệu có trong tệp bạn vừa mở để đảm bảo rằng nó ở đúng định dạng. Mỗi tệp dữ liệu chứa một loạt câu trả lời của học sinh ở định dạng sau:
#
# Đây là một mẫu chạy chương trình
# ```
# Enter a class to grade (i.e. class1 for class1.txt): class1
# Successfully opened class1.txt
# **** ANALYZING ****
# No errors found!
# **** REPORT ****
# Total valid lines of data: 20
# Total invalid lines of data: 0
# Enter a class to grade (i.e. class1 for class1.txt): class2
# Successfully opened class2.txt
# **** ANALYZING ****
# Invalid line of data: does not contain exactly 26 values:
# N00000023,,A,D,D,C,B,D,A,C,C,,C,,B,A,C,B,D,A,C,A,A
# Invalid line of data: N# is invalid
# N0000002,B,A,D,D,C,B,D,A,C,D,D,D,A,,A,C,D,,A,C,A,A,B,D,D
# Invalid line of data: N# is invalid
# NA0000027,B,A,D,D,,B,,A,C,B,D,B,A,,A,C,B,D,A,,A,A,B,D,D
# Invalid line of data: does not contain exactly 26 values:
# N00000035,B,A,D,D,B,B,,A,C,,D,B,A,B,A,A,B,D,A,C,A,C,B,D,D,A,A
# **** REPORT ****
# Total valid lines of data: 21
# Total invalid lines of data: 4
# ```

# %%
def analyze_file():
    try:
        while True:
            a = input("Enter file name: ")
            path = a + '.txt'
            try:
                o = open(path,'r')
            except Exception as e:
                print(f"Error: {e}")
            else: 
                print('Success Opened')
                print('ANALYZING')
            k = 0 # number of lines
            error = 0 # number of lines error
            for line in o.readlines(): # Vòng lặp kiểm tra các lỗi của dữ liệu
                k += 1
                listValue = line.rstrip("\n").split(",")
                if len(listValue) != 26:
                    print("Invalid line of data: does not contain exactly 26 values: \n")
                    print(line,"\n")
                    error += 1
                elif not listValue[0][1:].isnumeric() or len(listValue[0]) !=9:
                    print("Invalid line of data: N# is invalid \n")
                    print(line, "\n")
                    error += 1
                                  
            if error == 0:
                print('No errors found\n')
            print('*** REPORT ***')
            print("Total valid lines of data: ", k - error,"\n")
            print("Total invalid lines of data: ", error,"\n")

            choice = input("Do you want nhập thêm không? (0: không, 1: có)")
            
            if choice == "0":
                print("Thank for use this app !")
                break
    except Exception as e:
        print(e)

# %%
analyze_file()
# Out:
# Success Opened
# ANALYZING
# No errors found
#
# *** REPORT ***
# Total valid lines of data:  20
#
# Total invalid lines of data:  0
#
# Goodbye - Thank you !

# %% [markdown]
# ### Task 3
# Tiếp theo, bạn sẽ viết chương trình để chấm điểm các bài thi cho một phần nhất định. Kỳ thi gồm 25 câu hỏi, trắc nghiệm. Đây là một chuỗi đại diện cho các câu trả lời:
# ```
# answer_key = "B,A,D,D,C,B,D,A,C,C,D,B,A,B,A,C,B,D,A,C,A,A,B,D,D"
# ```
#
# Chương trình sẽ sử dụng những câu trả lời này để tính điểm cho mỗi dòng dữ liệu hợp lệ. Điểm có thể được tính như sau:
#
# * +4 điểm cho mỗi câu trả lời đúng
# * 0 điểm cho mỗi câu trả lời bị bỏ qua
# * -1 điểm cho mỗi câu trả lời sai
#
# Chúng ta cũng cần thống kê các yêu cầu sau:
# * Đếm số lượng học sinh đạt điểm cao (>80).
#
# * Điểm trung bình.
#
# * Điểm cao nhất.
#
# * Điểm thấp nhất.
#
# * Miền giá trị của điểm (cao nhất trừ thấp nhất).
#
# * Giá trị trung vị (Sắp xếp các điểm theo thứ tự tăng dần. Nếu # học sinh là số lẻ, bạn có thể lấy giá trị nằm ở giữa của tất cả các điểm (tức là [0, 50, 100] — trung vị là 50). Nếu # học sinh là chẵn bạn có thể tính giá trị trung vị bằng cách lấy giá trị trung bình của hai giá trị giữa (tức là [0, 50, 60, 100] — giá trị trung vị là 55)).
#
# * Trả về các câu hỏi bị học sinh bỏ qua nhiều nhất theo thứ tự: số thứ tự câu hỏi - số lượng học sinh bỏ qua -  tỉ lệ bị bỏ qua (nếu có cùng số lượng cho nhiều câu hỏi bị bỏ thì phải liệt kê ra đầy đủ).
#
# * Trả về các câu hỏi bị học sinh sai qua nhiều nhất theo thứ tự: số thứ tự câu hỏi - số lượng học sinh trả lời sai - tỉ lệ bị sai (nếu có cùng số lượng cho nhiều câu hỏi bị sai thì phải liệt kê ra đầy đủ).
#
# *Lưu ý: các giá trị số thực làm tròn 3 chữ số thập phân*

# %%
def analyze_evaluate_file():
    try:
        while True:
            a = input("Enter file name: ")
            path = a + '.txt'
            try:
                o = open(path,'r')
            except Exception as e:
                print(f"Error: {e}")
            else: 
                print('Success Opened')
                print('ANALYZING')
            k = 0 # number of lines
            error = 0 # number of lines error
            grade = [] # list grade
            valid_line = [] #
            answer_key = "B,A,D,D,C,B,D,A,C,C,D,B,A,B,A,C,B,D,A,C,A,A,B,D,D".split(",")
            
            for line in o.readlines(): # Create a loop for find an errors
                k += 1
                listValue = line.rstrip("\n").split(",")
                if len(listValue) != 26:
                    print("Invalid line of data: does not contain exactly 26 values: \n")
                    print(line,"\n")
                    error += 1
                elif not listValue[0][1:].isnumeric() or len(listValue[0]) !=9:
                    print("Invalid line of data: N# is invalid \n")
                    print(line, "\n")
                    error += 1
                else:
                    valid_line.append(listValue)                      
            for a1 in valid_line:
                # print(a1)
                answer = a1[1:]
                score = 0
                for a2 in range(25):
                    if answer[a2] == answer_key[a2]:
                        score += 4
                    elif answer[a2] == "":
                        score += 0
                    else:
                        score -= 1 
                    grade.append(score)
            if error == 0:
                print('No errors found\n')
            
            print('*** REPORT ***')                    
            print("Total valid lines of data: ", k - error,"\n")
            print("Total invalid lines of data: ", error,"\n")
            print("Mean (average) score:", sum(grade)/len(grade),"\n")
            print("Highest score", max(grade),"\n")
            print("Lowest score", min(grade),"\n")
            print("Range of scores", max(grade) - min(grade),"\n")
            s = sorted(grade)
            n = len(grade)
            if n % 2 == 1:
                median = s[n//2] 
            else:
                median = sum(s[n//2 - 1: n//2 + 1])/2.0
            print("Median score: ",median,"\n")

            choice = input("Do you want nhập thêm không? (0: không, 1: có)")
            if choice == "0":
                print("Thank for use this app !")
                break
    except Exception as e:
        print(e)

# %%
# analyze_evaluate_file()

# %% [markdown]
# ### Task 4
# Cuối cùng, yêu cầu chương trình là tạo một tệp “kết quả” chứa các kết quả chi tiết cho từng học sinh trong lớp. Mỗi dòng của tệp này phải chứa số ID của học sinh, dấu phẩy và sau đó là điểm của họ. Bạn nên đặt tên tệp này dựa trên tên tệp gốc được cung cấp — ví dụ: nếu người dùng chọn “class1.txt”, bạn nên lưu trữ kết quả trong tệp có tên “class1_grades.txt”.

# %%
def analyze_evaluate_record_file():
    try:
        while True:
            a = input("Enter file name: ")
            path = a + '.txt'
            try:
                o = open(path,'r')
            except Exception as e:
                print(f"Error: {e}")
            else: 
                print('Success Opened')
                print('ANALYZING')
            k = 0 # number of lines
            error = 0 # number of lines error
            grade = [] # list grade
            valid_line = [] #
            student_list = []
            answer_key = "B,A,D,D,C,B,D,A,C,C,D,B,A,B,A,C,B,D,A,C,A,A,B,D,D".split(",")
            
            for line in o.readlines(): # Create a loop for find an errors
                k += 1
                listValue = line.rstrip("\n").split(",")
                if len(listValue) != 26:
                    print("Invalid line of data: does not contain exactly 26 values: \n")
                    print(line,"\n")
                    error += 1
                elif not listValue[0][1:].isnumeric() or len(listValue[0]) !=9:
                    print("Invalid line of data: N# is invalid \n")
                    print(line, "\n")
                    error += 1
                else:
                    valid_line.append(listValue)                      
            for a1 in valid_line:
                # print(a1)
                student_list.append(a1[0])
                answer = a1[1:]
                score = 0
                for a2 in range(25):
                    if answer[a2] == answer_key[a2]:
                        score += 4
                    elif answer[a2] == "":
                        score += 0
                    else:
                        score -= 1 
                    grade.append(score)
            if error == 0:
                print('No errors found\n')
            
            print('*** REPORT ***')                    
            print("Total valid lines of data: ", k - error,"\n")
            print("Total invalid lines of data: ", error,"\n")
            print("Mean (average) score:", sum(grade)/len(grade),"\n")
            print("Highest score", max(grade),"\n")
            print("Lowest score", min(grade),"\n")
            print("Range of scores", max(grade) - min(grade),"\n")
            s = sorted(grade)
            n = len(grade)
            if n % 2 == 1:
                median = s[n//2] 
            else:
                median = sum(s[n//2 - 1: n//2 + 1])/2.0
            print("Median score: ",median,"\n")
            PATH = r'D:\AIO - Learning/MMC - Data Science - Pre AIO\0c. New Git/Test_repository/Final module 1/'
            FILE_PATH_GRADE = PATH + a + '_grade.txt'
    
            with open(FILE_PATH_GRADE,"w") as fw:
                for s, g in zip(student_list,grade):
                    fw.write(s + "," + str(g) + "\n")
                print("Sucessfully write file " + a + "_grade.txt \n")
            o.close()
            choice = input("Do you want nhập thêm không? (0: không, 1: có)")
            if choice == "0":
                print("Thank for use this app !")
                break
    except Exception as e:
        print(e)

# %%
# analyze_evaluate_record_file()

# %% [markdown]
# ### Task 5
# Dùng Numpy và Pandas để làm lại các bước trên

# %%
import numpy as np
import pandas as pd

# %%
for i in range(1,9):
    PATH = r'D:\AIO - Learning/MMC - Data Science - Pre AIO\0c. New Git/Test_repository/Final module 1/class'+ str(i) + ".txt"
    FILE_PATH_DATA_TASK_5 = r'D:\AIO - Learning/MMC - Data Science - Pre AIO\0c. New Git/Test_repository/Final module 1/class'+ str(i) + "_task5.txt"
    with open(PATH,"r") as f:
        with open(FILE_PATH_DATA_TASK_5,"w") as fw:
            for line in f.readlines():
                listValue = line.rstrip("\n").split(",")
                if len(listValue) == 26 and listValue[0][1:].isnumeric() and len(listValue[0]) == 9:
                    fw.write(line)
while True:
    filename = input("Enter name class: ") 
    FILE_PATH = r'D:\AIO - Learning/MMC - Data Science - Pre AIO\0c. New Git/Test_repository/Final module 1/' + filename + "_task5.txt"
    try:
        df = pd.read_csv(FILE_PATH,delimiter=",",header = None, index_col=0)
        df.index.name = "student_number"
        df = df.fillna(0)
    except Exception as e:
        print(e)
    else:
        print("\n SUCCESSFULLY OPENED",filename)
        break;
# df
grade = [] # list grade

answer_key = "B,A,D,D,C,B,D,A,C,C,D,B,A,B,A,C,B,D,A,C,A,A,B,D,D".split(",")

for i in range(df.shape[0]):
    score = 0
    for j in range (df.shape[1]):
        if df.iloc[i,j] == answer_key[j]:
            score += 4
        elif df.iloc[i,j] == 0:
            score += 0
        else:
            score -= 1
    grade.append(score)
    
df["score"] = grade


print("**** REPORT ****\n")
print("Total valid lines of data: ", df.shape[0],"\n")
print("Mean (average) score:", df["score"].mean(),"\n")
print("Highest score", df["score"].max(),"\n")
print("Lowest score", df["score"].min(),"\n")
print("Range of scores", df["score"].max() - df["score"].min(),"\n")
print("Median score: ",df["score"].median(),"\n")
# Out:
#  SUCCESSFULLY OPENED class1
# **** REPORT ****
#
# Total valid lines of data:  20
#
# Mean (average) score: 75.6
#
# Highest score 91
#
# Lowest score 59
#
# Range of scores 32
#
# Median score:  73.0
